# %% [markdown]
# <a href="https://www.kaggle.com/code/hugogrou/projeto-cdg?scriptVersionId=299506364" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Inspeção Inicial do Dataset

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/madhu41289/avazu-ctr-prediction-exp/sampleSubmission/sampleSubmission.csv
# /kaggle/input/datasets/madhu41289/avazu-ctr-prediction-exp/test/test.csv
# /kaggle/input/datasets/madhu41289/avazu-ctr-prediction-exp/train/train.csv

# %% [markdown]
# Bernardo Fernandes

# %%
import pandas as pd
import numpy as np

file_path = "/kaggle/input/datasets/madhu41289/avazu-ctr-prediction-exp/train/train.csv"
chunk_size = 1_000_000

total_rows = 0
null_counts = None
duplicate_count = 0
columns = None
dtypes = None

seen_hashes = set()

# Para guardar amostra para estatísticas completas
sample_data = []

print("A processar dataset em blocos...\n")

for i, chunk in enumerate(pd.read_csv(file_path, chunksize=chunk_size)):
    
    print(f"Bloco {i+1} carregado:", chunk.shape)
    
    total_rows += len(chunk)
    
    # Guardar primeiras 5 linhas
    if i == 0:
        first_rows = chunk.head()
        columns = chunk.columns.tolist()
        dtypes = chunk.dtypes
    
    # Guardar amostra até 2M linhas
    if len(sample_data) < 2:
        sample_data.append(chunk)
    
    # Valores nulos
    if null_counts is None:
        null_counts = chunk.isnull().sum()
    else:
        null_counts += chunk.isnull().sum()
    
    # Duplicados reais
    row_hashes = pd.util.hash_pandas_object(chunk, index=False)
    for h in row_hashes:
        if h in seen_hashes:
            duplicate_count += 1
        else:
            seen_hashes.add(h)

# Criar dataframe de amostra
df_sample = pd.concat(sample_data, ignore_index=True)

print(" RESULTADOS GERAIS ")

# DIMENSÃO

print("Dimensão do dataset (linhas, colunas):", (total_rows, len(columns)))

print("Primeiras 5 linhas:")
print(first_rows)

# VARIÁVEIS

print("Número de variáveis:", len(columns))
print("Lista das variáveis:")
print(columns)

# TIPOS

print("Tipos de dados:")
print(dtypes)

# NULOS

print("Valores nulos por coluna:")
print(null_counts)
print("Total de valores nulos:", null_counts.sum())

# DUPLICADOS

print("Número total de duplicados reais:", duplicate_count)


# ESTATÍSTICAS NUMÉRICAS COMPLETAS


print(" ESTATÍSTICAS NUMÉRICAS ")

numeric_cols = df_sample.select_dtypes(include=["int64", "float64"])

if len(numeric_cols.columns) > 0:
    print(numeric_cols.describe(percentiles=[0.25, 0.5, 0.75]))
else:
    print("Não existem variáveis numéricas.")


# ESTATÍSTICAS CATEGÓRICAS


print(" ESTATÍSTICAS CATEGÓRICAS ")

categorical_cols = df_sample.select_dtypes(include=["object"])

if len(categorical_cols.columns) > 0:
    print(categorical_cols.describe())
else:
    print("Não existem variáveis categóricas.")
# Out:
# A processar dataset em blocos...
#
# Bloco 1 carregado: (1000000, 24)
# Bloco 2 carregado: (1000000, 24)
# Bloco 3 carregado: (1000000, 24)
# Bloco 4 carregado: (1000000, 24)
# Bloco 5 carregado: (1000000, 24)
# Bloco 6 carregado: (1000000, 24)
# Bloco 7 carregado: (1000000, 24)
# Bloco 8 carregado: (1000000, 24)
# Bloco 9 carregado: (1000000, 24)
# Bloco 10 carregado: (1000000, 24)
# Bloco 11 carregado: (1000000, 24)
# Bloco 12 carregado: (1000000, 24)
# Bloco 13 carregado: (1000000, 24)
# Bloco 14 carregado: (1000000, 24)
# Bloco 15 carregado: (1000000, 24)
# Bloco 16 carregado: (1000000, 24)
# Bloco 17 carregado: (1000000, 24)
# Bloco 18 carregado: (1000000, 24)
# Bloco 19 carregado: (1000000, 24)
# Bloco 20 carregado: (1000000, 24)
# Bloco 21 carregado: (1000000, 24)
# Bloco 22 carregado: (1000000, 24)
# Bloco 23 carregado: (1000000, 24)
# Bloco 24 carregado: (1000000, 24)
# Bloco 25 carregado: (1000000, 24)
# Bloco 26 carregado: (1000000, 24)
# Bloco 27 carregado: (1000000, 24)
# Bloco 28 carregado: (1000000, 24)
# Bloco 29 carregado: (1000000, 24)
# Bloco 30 carregado: (1000000, 24)
# Bloco 31 carregado: (1000000, 24)
# Bloco 32 carregado: (1000000, 24)
# Bloco 33 carregado: (1000000, 24)
# Bloco 34 carregado: (1000000, 24)
# Bloco 35 carregado: (1000000, 24)
# Bloco 36 carregado: (1000000, 24)
# Bloco 37 carregado: (1000000, 24)
# Bloco 38 carregado: (1000000, 24)
# Bloco 39 carregado: (1000000, 24)
# Bloco 40 carregado: (1000000, 24)
# Bloco 41 carregado: (428967, 24)
#  RESULTADOS GERAIS
# Dimensão do dataset (linhas, colunas): (40428967, 24)
# Primeiras 5 linhas:
#              id  click      hour    C1  banner_pos   site_id site_domain  \
# 0  1.000009e+18      0  14102100  1005           0  1fbe01fe    f3845767
# 1  1.000017e+19      0  14102100  1005           0  1fbe01fe    f3845767
# 2  1.000037e+19      0  14102100  1005           0  1fbe01fe    f3845767
# 3  1.000064e+19      0  14102100  1005           0  1fbe01fe    f3845767
# 4  1.000068e+19      0  14102100  1005           1  fe8cc448    9166c161
#
#   site_category    app_id app_domain  ... device_type device_conn_type    C14  \
# 0      28905ebd  ecad2386   7801e8d9  ...           1                2  15706
# 1      28905ebd  ecad2386   7801e8d9  ...           1                0  15704
# 2      28905ebd  ecad2386   7801e8d9  ...           1                0  15704
# 3      28905ebd  ecad2386   7801e8d9  ...           1                0  15706
# 4      0569f928  ecad2386   7801e8d9  ...           1                0  18993
#
#    C15  C16   C17  C18  C19     C20  C21
# 0  320   50  1722    0   35      -1   79
# 1  320   50  1722    0   35  100084   79
# 2  320   50  1722    0   35  100084   79
# 3  320   50  1722    0   35  100084   79
# 4  320   50  2161    0   35      -1  157
#
# [5 rows x 24 columns]
# Número de variáveis: 24
# Lista das variáveis:
# ['id', 'click', 'hour', 'C1', 'banner_pos', 'site_id', 'site_domain', 'site_category', 'app_id', 'app_domain', 'app_category', 'device_id', 'device_ip', 'device_model', 'device_type', 'device_conn_type', 'C14', 'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21']
# Tipos de dados:
# id                  float64
# click                 int64
# hour                  int64
# C1                    int64
# banner_pos            int64
# site_id              object
# site_domain          object
# site_category        object
# app_id               object
# app_domain           object
# app_category         object
# device_id            object
# device_ip            object
# device_model         object
# device_type           int64
# device_conn_type      int64
# C14                   int64
# C15                   int64
# C16                   int64
# C17                   int64
# C18                   int64
# C19                   int64
# C20                   int64
# C21                   int64
# dtype: object
# Valores nulos por coluna:
# id                  0
# click               0
# hour                0
# C1                  0
# banner_pos          0
# site_id             0
# site_domain         0
# site_category       0
# app_id              0
# app_domain          0
# app_category        0
# device_id           0
# device_ip           0
# device_model        0
# device_type         0
# device_conn_type    0
# C14                 0
# C15                 0
# C16                 0
# C17                 0
# C18                 0
# C19                 0
# C20                 0
# C21                 0
# dtype: int64
# Total de valores nulos: 0
# Número total de duplicados reais: 0
#  ESTATÍSTICAS NUMÉRICAS
#                  id         click          hour            C1    banner_pos  \
# count  2.000000e+06  2.000000e+06  2.000000e+06  2.000000e+06  2.000000e+06
# mean   9.337745e+18  1.616045e-01  1.410210e+07  1.005012e+03  2.511090e-01
# std    5.378170e+18  3.680877e-01  2.573399e+00  1.030733e+00  4.668109e-01
# min    9.984920e+12  0.000000e+00  1.410210e+07  1.001000e+03  0.000000e+00
# 25%    4.555174e+18  0.000000e+00  1.410210e+07  1.005000e+03  0.000000e+00
# 50%    9.531133e+18  0.000000e+00  1.410210e+07  1.005000e+03  0.000000e+00
# 75%    1.401388e+19  0.000000e+00  1.410211e+07  1.005000e+03  0.000000e+00
# max    1.844673e+19  1.000000e+00  1.410211e+07  1.012000e+03  7.000000e+00
#
#         device_type  device_conn_type           C14           C15  \
# count  2.000000e+06      2.000000e+06  2.000000e+06  2.000000e+06
# mean   1.006004e+00      2.346770e-01  1.842631e+04  3.185641e+02
# std    4.172392e-01      6.933022e-01  3.767175e+03  1.972680e+01
# min    0.000000e+00      0.000000e+00  3.750000e+02  1.200000e+02
# 25%    1.000000e+00      0.000000e+00  1.570800e+04  3.200000e+02
# 50%    1.000000e+00      0.000000e+00  1.949300e+04  3.200000e+02
# 75%    1.000000e+00      0.000000e+00  2.161100e+04  3.200000e+02
# max    5.000000e+00      5.000000e+00  2.176300e+04  1.024000e+03
#
#                 C16           C17           C18           C19           C20  \
# count  2.000000e+06  2.000000e+06  2.000000e+06  2.000000e+06  2.000000e+06
# mean   5.700759e+01  2.062724e+03  1.577069e+00  1.905398e+02  4.530001e+04
# std    3.869259e+01  4.752705e+02  1.353921e+00  2.870427e+02  4.982698e+04
# min    2.000000e+01  1.120000e+02  0.000000e+00  3.300000e+01 -1.000000e+00
# 25%    5.000000e+01  1.722000e+03  0.000000e+00  3.500000e+01 -1.000000e+00
# 50%    5.000000e+01  2.201000e+03  2.000000e+00  3.900000e+01 -1.000000e+00
# 75%    5.000000e+01  2.480000e+03  3.000000e+00  1.750000e+02  1.000840e+05
# max    1.024000e+03  2.505000e+03  3.000000e+00  1.835000e+03  1.002480e+05
#
#                 C21
# count  2.000000e+06
# mean   6.807638e+01
# std    4.136320e+01
# min    1.300000e+01
# 25%    4.300000e+01
# 50%    6.100000e+01
# 75%    7.900000e+01
# max    2.210000e+02
#  ESTATÍSTICAS CATEGÓRICAS
#          site_id site_domain site_category    app_id app_domain app_category  \
# count    2000000     2000000       2000000   2000000    2000000      2000000
# unique      2473        2653            22      3108        206           27
# top     85f751fd    c4e18dd6      50e219e0  ecad2386   7801e8d9     07d7df22
# freq      695705      725669        759388   1304295    1369155      1326611
#
#        device_id device_ip device_model
# count    2000000   2000000      2000000
# unique    163262    557935         5253
# top     a99f214a  6b9769f2     8a4875bd
# freq     1665877     10609       115104

# %% [markdown]
# Bernardo Fernandes
